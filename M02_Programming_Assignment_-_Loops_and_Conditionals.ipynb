# %%
#4.1
secret = 5

guess = input("Enter your guess for the secret number: ")

if guess < secret:
    print("Your guess is too low.")
elif guess > secret:
    print("Your guess is too high.")
else:
    print("Your guess is right.")

#4.2
small = False
green = True

if small:
    if green:
        print("Pea")
    else:
        print("Cherry")
else:
    if green:
        print("Watermelon")
    else:
        print("WPumpkin")

#6.1
for value in [3, 2, 1, 0]:
    print(value)

#6.2
guess_me = 7
number = 1
while True:
    if number < guess_me:
        print("Your guess is too low.")
    elif number == guess_me:
        print("You found the number.")
        break
    elif number > guess_me:
        print("Oops. The number went past the guessing number.")
        break
    number += 1

#6.3
guess_me = 5
for number in range(10):
    if number < guess_me:
        print("Your guess is too low.")
    elif number == guess_me:
        print("You found the number.")
        break
    elif number > guess_me:
        print("Oops. The number went past the guessing number.")
        break
